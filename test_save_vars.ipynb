# %% [markdown]
# # Test save_vars() functionality
# This notebook tests the save_vars() function to store variables in metadata.

# %%
# %load_ext ipycalc

# %%
# Define some test variables
P = 10.5  # A simple scalar
L = 20.0
label = 'Test Beam'

# %%
# Use ipycalc to create a variable with units
# %%calc
Force: F = 100 * kip
Length: l = 15 * ft

# %%
# Save all current variables to notebook metadata
save_vars()

# %% [markdown]
# The variables have been saved. Check the notebook's .ipynb JSON file to verify that metadata['ipycalc_vars'] contains the saved variables.
