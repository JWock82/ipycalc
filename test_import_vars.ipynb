# %% [markdown]
# # Test import_vars() functionality
# This notebook tests the import_vars() function to load variables from test_save_vars.ipynb.

# %%
# %load_ext ipycalc

# %%
# Import all variables from test_save_vars.ipynb
import_vars('test_save_vars.ipynb')

# %%
# Verify the imported variables are available
print('P:', P)
print('L:', L)
print('label:', label)
print('F:', F)
print('l:', l)

# %%
# Test filtering: import only specific variables from test_save_vars.ipynb
import_vars('test_save_vars.ipynb', 'P', 'L')

# %% [markdown]
# Variables have been imported successfully!
